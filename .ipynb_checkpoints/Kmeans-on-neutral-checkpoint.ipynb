# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import confusion_matrix

# %%
# json_data = pd.read_json("foliohd_data.json")
open_json_data = open("foliohd_data.json")
json_data = json.load(open_json_data)
open_json_data.close()

json_data.keys()

json_data["features_by_type"].keys()

json_data["feature_labels"]

# df = pd.DataFrame()
# json_data["feature_labels"]
# whooops. I guess I don't have the actual event names here

# Each row of the dataframe should be a person
# Each column is an event type

open_event_names = open("event_type_names.json")
event_names = json.load(open_event_names)
open_event_names.close()

person_list = []

json_data["features_by_type"]["upgraded"].values()

upgraded_df = pd.DataFrame(json_data["features_by_type"]["upgraded"].values())
neutral_df = pd.DataFrame(json_data["features_by_type"]["neutral"].values())
churned_df = pd.DataFrame(json_data["features_by_type"]["churned"].values())

# A key for the prefixes in the event types
prefixes = {
            "tbfe_n": "before_first_session_count",
            "oec_n": "overall_event_count",
            "fsec_n": "first_session_event_count",
            "ssec_n": "subsequent_session_event_count"
            }
# Add a column indicating the known class for that person
# 0 => churned
# 1 => upgraded
# 2 => neutral (undecided)

c = list(np.zeros(len(churned_df)))
u = list(np.ones(len(upgraded_df)))
n = list(2*np.ones(len(neutral_df)))

churned_df["Result"] = c
neutral_df["Result"] = n
upgraded_df["Result"] = u

data_df = upgraded_df.append([neutral_df, churned_df])

# loop through the current column names
# calculate desired name for each current name
# push desired name onto list of new column names
# assign new column names to dataframe

new_columns = []
for col in churned_df.columns:
    if ":" in col: # check for column names with ids, which will have a colon
        first, second = col.split(":")
        name = event_names[second]
        new_col = first + ":" + name
        new_columns.append(new_col)
    else:
        new_columns.append(col)
        
churned_df.columns = new_columns

new_columns = []
for col in neutral_df.columns:
    if ":" in col: # check for column names with ids, which will have a colon
        first, second = col.split(":")
        name = event_names[second] # get readable name for the id
        new_col = first + ":" + name # create new column name
        new_columns.append(new_col)
    else:
        new_columns.append(col)
        
neutral_df.columns = new_columns

new_columns = []
for col in upgraded_df.columns:
    if ":" in col: # check for column names with ids, which will have a colon
        first, second = col.split(":")
        name = event_names[second] # get readable name for the id
        new_col = first + ":" + name # create new column name
        new_columns.append(new_col)
    else:
        new_columns.append(col)
        
upgraded_df.columns = new_columns

data_df = upgraded_df.append(churned_df)

all_columns = list(data_df.columns)

# %%
columns = []

for i in all_columns:
    if (i.find("tbfe") == -1 and i.find("oec") == -1):
        columns.append(i)
        
for i in columns:
    print i
# Out:
# Result
# avg_length_session_m
# avg_per_day_events_n
# avg_per_day_session_n
# avg_time_between_session_h
# fsec_n:!error-cant-feature-media
# fsec_n:!error-linking-document
# fsec_n:!error-linking-video
# fsec_n:!error-one-feature-video-only
# fsec_n:!error-uploading
# fsec_n:*viewed:media
# fsec_n:*viewed:page
# fsec_n:avatar-delete
# fsec_n:avatar-upload
# fsec_n:deleted
# fsec_n:deleted-survey
# fsec_n:domain_purchase
# fsec_n:free_domain_claim
# fsec_n:gallery-create
# fsec_n:gallery-delete
# fsec_n:gallery-edit
# fsec_n:gallery-reorder
# fsec_n:help
# fsec_n:incoming_message
# fsec_n:loaded-manager
# fsec_n:loaded-settings
# fsec_n:loaded-theme-switcher
# fsec_n:media-delete
# fsec_n:media-edit
# fsec_n:media-feature
# fsec_n:media-unfeature
# fsec_n:media-upload
# fsec_n:opened gallery-editor
# fsec_n:opened media-editor
# fsec_n:opened uploader
# fsec_n:opened:add-document
# fsec_n:opened:add-video
# fsec_n:opened:gallery-editor
# fsec_n:opened:media-editor
# fsec_n:opened:upload-image
# fsec_n:opened:uploader
# fsec_n:outgoing_email
# fsec_n:outgoing_message
# fsec_n:password-changed
# fsec_n:password-forgot
# fsec_n:register
# fsec_n:theme-changed
# fsec_n:updated-pref-contactemail
# fsec_n:updated-pref-externallinkname
# fsec_n:updated-pref-externallinkurl
# fsec_n:updated-pref-facebookurl
# fsec_n:updated-pref-fotomotoid
# fsec_n:updated-pref-googleanalyticsid
# fsec_n:updated-pref-linkedinurl
# fsec_n:updated-pref-ownerbiotext
# fsec_n:updated-pref-twitterurl
# fsec_n:updated-pref-websiteurl
# ssec_n:!error-cant-feature-media
# ssec_n:!error-linking-document
# ssec_n:!error-linking-video
# ssec_n:!error-one-feature-video-only
# ssec_n:!error-uploading
# ssec_n:*viewed:media
# ssec_n:*viewed:page
# ssec_n:avatar-delete
# ssec_n:avatar-upload
# ssec_n:deleted
# ssec_n:deleted-survey
# ssec_n:domain_purchase
# ssec_n:emailforwarding-failed
# ssec_n:free_domain_claim
# ssec_n:gallery-create
# ssec_n:gallery-delete
# ssec_n:gallery-edit
# ssec_n:gallery-reorder
# ssec_n:help
# ssec_n:incoming_message
# ssec_n:loaded-manager
# ssec_n:loaded-settings
# ssec_n:loaded-theme-switcher
# ssec_n:media-delete
# ssec_n:media-edit
# ssec_n:media-feature
# ssec_n:media-unfeature
# ssec_n:media-upload
# ssec_n:opened gallery-editor
# ssec_n:opened media-editor
# ssec_n:opened uploader
# ssec_n:opened:add-document
# ssec_n:opened:add-video
# ssec_n:opened:gallery-editor
# ssec_n:opened:media-editor
# ssec_n:opened:upload-image
# ssec_n:opened:uploader
# ssec_n:outgoing_email
# ssec_n:outgoing_message
# ssec_n:password-changed
# ssec_n:password-forgot
# ssec_n:register
# ssec_n:support
# ssec_n:theme-changed
# ssec_n:updated-pref-contactemail
# ssec_n:updated-pref-externallinkname
# ssec_n:updated-pref-externallinkurl
# ssec_n:updated-pref-facebookurl
# ssec_n:updated-pref-fotomotoid
# ssec_n:updated-pref-googleanalyticsid
# ssec_n:updated-pref-linkedinurl
# ssec_n:updated-pref-ownerbiotext
# ssec_n:updated-pref-twitterurl
# ssec_n:updated-pref-websiteurl
# ssec_n:viewed:alert-email

# %%
for col in columns:
    if
# Out:
# False
