# %%
# What percentage of people have a triggered an event at least once?
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
# json_data = pd.read_json("foliohd_data.json")
open_json_data = open("foliohd_data.json")
json_data = json.load(open_json_data)
open_json_data.close()

json_data.keys()

json_data["features_by_type"].keys()

json_data["feature_labels"]

# df = pd.DataFrame()
# json_data["feature_labels"]
# whooops. I guess I don't have the actual event names here

# Each row of the dataframe should be a person
# Each column is an event type

open_event_names = open("event_type_names.json")
event_names = json.load(open_event_names)
open_event_names.close()

person_list = []

json_data["features_by_type"]["upgraded"].values()

upgraded_df = pd.DataFrame(json_data["features_by_type"]["upgraded"].values())
neutral_df = pd.DataFrame(json_data["features_by_type"]["neutral"].values())
churned_df = pd.DataFrame(json_data["features_by_type"]["churned"].values())

# A key for the prefixes in the event types
prefixes = {
            "tbfe_n": "before_first_session_count",
            "oec_n": "overall_event_count",
            "fsec_n": "first_session_event_count",
            "ssec_n": "subsequent_session_event_count"
            }
# Add a column indicating the known class for that person
# 0 => churned
# 1 => upgraded
# 2 => neutral (undecided)

c = list(np.zeros(len(churned_df)))
u = list(np.ones(len(upgraded_df)))
n = list(2*np.ones(len(neutral_df)))

churned_df["Result"] = c
neutral_df["Result"] = n
upgraded_df["Result"] = u

data_df = upgraded_df.append([neutral_df, churned_df])

# loop through the current column names
# calculate desired name for each current name
# push desired name onto list of new column names
# assign new column names to dataframe

new_columns = []
for col in churned_df.columns:
    if ":" in col: # check for column names with ids, which will have a colon
        first, second = col.split(":")
        name = event_names[second]
        new_col = first + ":" + name
        new_columns.append(new_col)
    else:
        new_columns.append(col)
        
churned_df.columns = new_columns

new_columns = []
for col in neutral_df.columns:
    if ":" in col: # check for column names with ids, which will have a colon
        first, second = col.split(":")
        name = event_names[second] # get readable name for the id
        new_col = first + ":" + name # create new column name
        new_columns.append(new_col)
    else:
        new_columns.append(col)
        
neutral_df.columns = new_columns

new_columns = []
for col in upgraded_df.columns:
    if ":" in col: # check for column names with ids, which will have a colon
        first, second = col.split(":")
        name = event_names[second] # get readable name for the id
        new_col = first + ":" + name # create new column name
        new_columns.append(new_col)
    else:
        new_columns.append(col)
        
upgraded_df.columns = new_columns

data_df = upgraded_df.append(churned_df)

all_columns = list(data_df.columns)

# %%
freqs = {}
counter_columns = []

for col in data_df.columns:
    if (col.find("oec") != -1):
        counter_columns.append(col)

for col in counter_columns:
    triggered = 0
    for i in data_df[col]:
        if (not(np.isnan(i)) and i != 0):
            triggered += 1
    freqs[col] = float(triggered) / len(data_df[col])
    
freqs
# Out:
# {u'oec_n:!error-cant-feature-media': 0.008073531238355483,
#  u'oec_n:!error-linking-document': 0.10508011427151906,
#  u'oec_n:!error-linking-video': 0.0393739908085952,
#  u'oec_n:!error-one-feature-video-only': 0.0028567879766488633,
#  u'oec_n:!error-uploading': 0.01304185815426655,
#  u'oec_n:*viewed:media': 0.010681902869208794,
#  u'oec_n:*viewed:page': 0.011923984598186561,
#  u'oec_n:avatar-delete': 0.023723761023475346,
#  u'oec_n:avatar-upload': 0.3147435101229661,
#  u'oec_n:deleted': 0.008073531238355483,
#  u'oec_n:deleted-survey': 0.0011178735560799901,
#  u'oec_n:domain_purchase': 0.0016147062476710968,
#  u'oec_n:emailforwarding-failed': 0.00012420817289777666,
#  u'oec_n:free_domain_claim': 0.0022357471121599803,
#  u'oec_n:gallery-create': 0.45398087194137376,
#  u'oec_n:gallery-delete': 0.25065209290771334,
#  u'oec_n:gallery-edit': 0.4451620916656316,
#  u'oec_n:gallery-reorder': 0.5258974040491864,
#  u'oec_n:help': 0.0027325798037510867,
#  u'oec_n:incoming_message': 0.03465408023847969,
#  u'oec_n:loaded-manager': 0.8474723636815302,
#  u'oec_n:loaded-settings': 0.13911315364550988,
#  u'oec_n:loaded-theme-switcher': 0.08582784747236367,
#  u'oec_n:media-delete': 0.46615327288535585,
#  u'oec_n:media-edit': 0.160725375729723,
#  u'oec_n:media-feature': 0.31275617935660166,
#  u'oec_n:media-unfeature': 0.21761271891690473,
#  u'oec_n:media-upload': 0.7939386411625885,
#  u'oec_n:opened gallery-editor': 0.020245932182337598,
#  u'oec_n:opened media-editor': 0.03403303937399081,
#  u'oec_n:opened uploader': 0.04583281579927959,
#  u'oec_n:opened:add-document': 0.05117376723388399,
#  u'oec_n:opened:add-video': 0.026332132654328655,
#  u'oec_n:opened:gallery-editor': 0.23239349149174016,
#  u'oec_n:opened:media-editor': 0.3841758787728233,
#  u'oec_n:opened:upload-image': 0.1511613464165942,
#  u'oec_n:opened:uploader': 0.42044466525897406,
#  u'oec_n:outgoing_email': 0.005837784126195504,
#  u'oec_n:outgoing_message': 0.011675568252391008,
#  u'oec_n:password-changed': 0.039746615327288536,
#  u'oec_n:password-forgot': 0.042106570612346295,
#  u'oec_n:register': 1.0,
#  u'oec_n:support': 0.0007452490373866601,
#  u'oec_n:theme-changed': 0.3741150167681033,
#  u'oec_n:updated-pref-contactemail': 0.03403303937399081,
#  u'oec_n:updated-pref-externallinkname': 0.0028567879766488633,
#  u'oec_n:updated-pref-externallinkurl': 0.0028567879766488633,
#  u'oec_n:updated-pref-facebookurl': 0.08458576574338592,
#  u'oec_n:updated-pref-fotomotoid': 0.003105204322444417,
#  u'oec_n:updated-pref-googleanalyticsid': 0.003850453359831077,
#  u'oec_n:updated-pref-linkedinurl': 0.04893802012172401,
#  u'oec_n:updated-pref-ownerbiotext': 0.24903738666004224,
#  u'oec_n:updated-pref-twitterurl': 0.07117128307042603,
#  u'oec_n:updated-pref-websiteurl': 0.05490001242081729,
#  u'oec_n:viewed:alert-email': 0.00012420817289777666}

# %%
import csv

# %%
# with open("event_frequencies.csv", "w") as csvfile:
#     writer = csv.writer(csvfile)
#     for i in freqs:
#         tmp = [i, freqs[i]]
#         writer.writerow([tmp[0], tmp[1]])
